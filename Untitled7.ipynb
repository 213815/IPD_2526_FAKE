# %% [markdown]
# <a href="https://colab.research.google.com/github/213815/IPD_2526_FAKE/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Setting up imports and loading the dataset
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

sns.set_style('whitegrid')

titanic = sns.load_dataset("titanic")
titanic = titanic.dropna(subset=['age', 'fare', 'sex', 'class', 'survived'])

# %%
sns.countplot(x='pclass', fill='survived', data=titanic)
plt.title("Survival by Ticket Class")
plt.show()

# %%
sns.countplot(x='pclass', hue='survived', data=titanic)
plt.title("Survival by Ticket Class")
plt.show()

# %%
sns.countplot(x='fare', hue='survived', data=titanic)
plt.title("Survival by Ticket Class")
plt.show()
